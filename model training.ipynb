# %%
import tensorflow as tf
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dropout,Flatten,Input,Dense,MaxPooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
tf.test.is_gpu_available()
# Out:
# WARNING:tensorflow:From C:\Users\thiru\AppData\Local\Temp\ipykernel_26700\337460670.py:1: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# False

# %%
train_datagen=ImageDataGenerator(rescale=1./255,rotation_range=0.2,shear_range=0.2,zoom_range=0.2,width_shift_range=0.2,height_shift_range=0.2,validation_split=0.2)

# %%
train_data=train_datagen.flow_from_directory(r"C:\Users\thiru\OneDrive\Desktop\DDD prj\train",target_size=(80,80),batch_size=8,class_mode='categorical',
                                            subset='training')
validation_data=train_datagen.flow_from_directory(r"C:\Users\thiru\OneDrive\Desktop\DDD prj\train",target_size=(80,80),batch_size=8,class_mode='categorical',
                                            subset='validation')
# Out:
# Found 2955 images belonging to 2 classes.
# Found 738 images belonging to 2 classes.

# %%
test_datagen=ImageDataGenerator(rescale=1./255)
test_data=test_datagen.flow_from_directory(r"C:\Users\thiru\OneDrive\Desktop\DDD prj\test",target_size=(80,80),batch_size=8,class_mode='categorical')
# Out:
# Found 414 images belonging to 2 classes.

# %%
bmodel=InceptionV3(include_top=False,weights='imagenet',input_tensor=Input(shape=(80,80,3)))
hmodel=bmodel.output
hmodel=Flatten()(hmodel)
hmodel=Dense(64,activation='relu',)(hmodel)
hmodel=Dropout(0.5)(hmodel)
hmodel=Dense(2,activation='softmax')(hmodel)


model = Model(inputs=bmodel.input ,outputs=hmodel )

for layer in bmodel.layers:
    layer.trainable = False

# %%
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_12 (InputLayer)       [(None, 80, 80, 3)]          0         []
#
#  conv2d_1034 (Conv2D)        (None, 39, 39, 32)           864       ['input_12[0][0]']
#
#  batch_normalization_1034 (  (None, 39, 39, 32)           96        ['conv2d_1034[0][0]']
#  BatchNormalization)
#
#  activation_1034 (Activatio  (None, 39, 39, 32)           0         ['batch_normalization_1034[0][
#  n)                                                                 0]']
#
#  conv2d_1035 (Conv2D)        (None, 37, 37, 32)           9216      ['activation_1034[0][0]']
#
#  batch_normalization_1035 (  (None, 37, 37, 32)           96        ['conv2d_1035[0][0]']
#  BatchNormalization)
#
#  activation_1035 (Activatio  (None, 37, 37, 32)           0         ['batch_normalization_1035[0][
# ...

# %%
batchsize=8

# %%
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping ,ReduceLROnPlateau

# %%
checkpoint = ModelCheckpoint(r"C:\Users\thiru\OneDrive\Desktop\DDD prj\models",
                            moniter='val_loss',save_best_only=True,verbose=3)
earlystop = EarlyStopping(monitor = 'val_loss', patience=7, verbose=3,restore_best_weights=True)
learning_rate=ReduceLROnPlateau(monitor='val_loss',patience=3, verbose=3 )
callbacks=[ checkpoint , earlystop , learning_rate]

# %%
model.compile(optimizer='Adam',loss='categorical_crossentropy',metrics=['accuracy'])
model.fit_generator(train_data,steps_per_epoch=train_data.samples//batchsize,validation_data=validation_data,
                    validation_steps=validation_data.samples//batchsize,
                    callbacks=callbacks,epochs=50)
# Out:
# Epoch 1/50
# C:\Users\thiru\AppData\Local\Temp\ipykernel_26700\2041135280.py:2: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model.fit_generator(train_data,steps_per_epoch=train_data.samples//batchsize,validation_data=validation_data,
# 369/369 [==============================] - ETA: 0s - loss: 0.0227 - accuracy: 0.9946
# Epoch 1: val_loss did not improve from 0.03675
# 369/369 [==============================] - 45s 106ms/step - loss: 0.0227 - accuracy: 0.9946 - val_loss: 0.1156 - val_accuracy: 0.9742 - lr: 0.0010
# Epoch 2/50
# 369/369 [==============================] - ETA: 0s - loss: 0.0297 - accuracy: 0.9912
# Epoch 2: val_loss did not improve from 0.03675
# 369/369 [==============================] - 38s 103ms/step - loss: 0.0297 - accuracy: 0.9912 - val_loss: 0.1124 - val_accuracy: 0.9755 - lr: 0.0010
# Epoch 3/50
# ...

# %%
acc_tr , loss_tr = model.evaluate_generator(train_data)
print(acc_tr)
print(loss_tr)
print(acc_tr)
# Out:
# C:\Users\thiru\AppData\Local\Temp\ipykernel_26700\356732524.py:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   acc_tr , loss_tr = model.evaluate_generator(train_data)
# 0.005024814046919346
# 0.9986463785171509
# 0.005024814046919346

# %%
acc_vr , loss_vr = model.evaluate_generator(validation_data)
print(acc_vr)
print(loss_vr)
# Out:
# C:\Users\thiru\AppData\Local\Temp\ipykernel_26700\3523792914.py:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   acc_vr , loss_vr = model.evaluate_generator(validation_data)
# 0.044506072998046875
# 0.9878048896789551

# %%
acc_test , loss_test = model.evaluate_generator(test_data)
print(acc_test)
print(loss_test)
# Out:
# C:\Users\thiru\AppData\Local\Temp\ipykernel_26700\3153334047.py:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   acc_test , loss_test = model.evaluate_generator(test_data)
# 0.15132379531860352
# 0.9734299778938293
